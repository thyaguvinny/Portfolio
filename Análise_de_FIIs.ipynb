# %% [markdown]
# <a href="https://colab.research.google.com/github/thyaguvinny/Portfolio/blob/main/An%C3%A1lise_de_FIIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 0. Importando bibliotecas

# %%
# Importar Bibliotecas
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# ## 1. Definindo cabeçalho da requisição

# %%
url='https://fiis.com.br/resumo'
headers = {
    'User-Agent':
        'Mozilla/5.0 (Machintosh; Intel Mac OS X 10_11_4) AppleWebKit/537.36'
        ' (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36'
}

# %%
response = requests.get(url, headers=headers)
if response.status_code == 200:
  df = pd.read_html(response.content, encoding='utf-8')[0]

# %%
#df.sort_values('Ticker', inplace=True)
df
# Out:
#     Ticker  Último Rend. (R$)  Último Rend. (%)  Data Pagamento  Data Base  \
# 0      NaN                NaN               NaN             NaN        NaN
# 1      NaN                NaN               NaN             NaN        NaN
# 2      NaN                NaN               NaN             NaN        NaN
# 3      NaN                NaN               NaN             NaN        NaN
# 4      NaN                NaN               NaN             NaN        NaN
# 5      NaN                NaN               NaN             NaN        NaN
# 6      NaN                NaN               NaN             NaN        NaN
# 7      NaN                NaN               NaN             NaN        NaN
# 8      NaN                NaN               NaN             NaN        NaN
# 9      NaN                NaN               NaN             NaN        NaN
# 10     NaN                NaN               NaN             NaN        NaN
# ...
